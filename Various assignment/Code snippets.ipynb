# %%
from Bio._py3k import urlopen as _urlopen
from Bio._py3k import _binary_to_string_handle


def _q(op, arg1, arg2=None, arg3=None):
    URL = "http://rest.kegg.jp/%s"
    if arg2 and arg3:
        args = "%s/%s/%s/%s" % (op, arg1, arg2, arg3)
    elif arg2:
        args = "%s/%s/%s" % (op, arg1, arg2)
    else:
        args = "%s/%s" % (op, arg1)
    resp = _urlopen(URL % (args))

    if "image" == arg2:
        return resp

    return _binary_to_string_handle(resp)

def kegg_conv(target_db, source_db, option=None):
    if option and option not in ["turtle", "n-triple"]:
        raise Exception("Invalid option arg for kegg conv request.")

    if isinstance(source_db, list):
        source_db = "+".join(source_db)

    if target_db in ["ncbi-gi", "ncbi-geneid", "ncbi-proteinid", "uniprot", "genes"] or \
       source_db in ["ncbi-gi", "ncbi-geneid", "ncbi-proteinid", "uniprot", "genes"] or \
       (target_db in ["drug", "compound", "glycan"] and
           source_db in ["pubchem", "glycan"]) or \
       (target_db in ["pubchem", "glycan"] and
           source_db in ["drug", "compound", "glycan"]):

        if option:
            resp = _q("conv", target_db, source_db, option)
        else:
            resp = _q("conv", target_db, source_db)

        return resp
    else:
        raise Exception("Bad argument target_db or source_db for kegg conv request.")

# %%
from Bio.KEGG import REST

# %%
paths = REST.kegg_list("pathway").read()

# %%
print(paths)
# Out:
# path:map00010	Glycolysis / Gluconeogenesis
# path:map00020	Citrate cycle (TCA cycle)
# path:map00030	Pentose phosphate pathway
# path:map00040	Pentose and glucuronate interconversions
# path:map00051	Fructose and mannose metabolism
# path:map00052	Galactose metabolism
# path:map00053	Ascorbate and aldarate metabolism
# path:map00061	Fatty acid biosynthesis
# path:map00062	Fatty acid elongation
# path:map00071	Fatty acid degradation
# path:map00072	Synthesis and degradation of ketone bodies
# path:map00073	Cutin, suberine and wax biosynthesis
# path:map00100	Steroid biosynthesis
# path:map00120	Primary bile acid biosynthesis
# path:map00121	Secondary bile acid biosynthesis
# path:map00130	Ubiquinone and other terpenoid-quinone biosynthesis
# path:map00140	Steroid hormone biosynthesis
# path:map00190	Oxidative phosphorylation
# path:map00195	Photosynthesis
# path:map00196	Photosynthesis - antenna proteins
# path:map00220	Arginine biosynthesis
# path:map00230	Purine metabolism
# path:map00232	Caffeine metabolism
# path:map00240	Pyrimidine metabolism
# path:map00250	Alanine, aspartate and glutamate metabolism
# path:map00253	Tetracycline biosynthesis
# path:map00254	Aflatoxin biosynthesis
# path:map00260	Glycine, serine and threonine metabolism
# path:map00261	Monobactam biosynthesis
# path:map00270	Cysteine and methionine metabolism
# path:map00280	Valine, leucine and isoleucine degradation
# path:map00281	Geraniol degradation
# path:map00290	Valine, leucine and isoleucine biosynthesis
# path:map00300	Lysine biosynthesis
# path:map00310	Lysine degradation
# path:map00311	Penicillin and cephalosporin biosynthesis
# path:map00330	Arginine and proline metabolism
# path:map00331	Clavulanic acid biosynthesis
# path:map00332	Carbapenem biosynthesis
# path:map00333	Prodigiosin biosynthesis
# path:map00340	Histidine metabolism
# path:map00350	Tyrosine metabolism
# path:map00360	Phenylalanine metabolism
# path:map00361	Chlorocyclohexane and chlorobenzene degradation
# path:map00362	Benzoate degradation
# path:map00363	Bisphenol degradation
# path:map00364	Fluorobenzoate degradation
# path:map00365	Furfural degradation
# path:map00380	Tryptophan metabolism
# path:map00400	Phenylalanine, tyrosine and tryptophan biosynthesis
# path:map00401	Novobiocin biosynthesis
# path:map00402	Benzoxazinoid biosynthesis
# path:map00403	Indole diterpene alkaloid biosynthesis
# path:map00404	Staurosporine biosynthesis
# path:map00405	Phenazine biosynthesis
# path:map00410	beta-Alanine metabolism
# path:map00430	Taurine and hypotaurine metabolism
# path:map00440	Phosphonate and phosphinate metabolism
# path:map00450	Selenocompound metabolism
# path:map00460	Cyanoamino acid metabolism
# path:map00471	D-Glutamine and D-glutamate metabolism
# path:map00472	D-Arginine and D-ornithine metabolism
# path:map00473	D-Alanine metabolism
# path:map00480	Glutathione metabolism
# path:map00500	Starch and sucrose metabolism
# path:map00510	N-Glycan biosynthesis
# path:map00511	Other glycan degradation
# path:map00512	Mucin type O-glycan biosynthesis
# path:map00513	Various types of N-glycan biosynthesis
# path:map00514	Other types of O-glycan biosynthesis
# path:map00515	Mannose type O-glycan biosynthesis
# path:map00520	Amino sugar and nucleotide sugar metabolism
# path:map00521	Streptomycin biosynthesis
# path:map00522	Biosynthesis of 12-, 14- and 16-membered macrolides
# path:map00523	Polyketide sugar unit biosynthesis
# path:map00524	Neomycin, kanamycin and gentamicin biosynthesis
# path:map00525	Acarbose and validamycin biosynthesis
# path:map00531	Glycosaminoglycan degradation
# path:map00532	Glycosaminoglycan biosynthesis - chondroitin sulfate / dermatan sulfate
# path:map00533	Glycosaminoglycan biosynthesis - keratan sulfate
# path:map00534	Glycosaminoglycan biosynthesis - heparan sulfate / heparin
# path:map00540	Lipopolysaccharide biosynthesis
# path:map00550	Peptidoglycan biosynthesis
# path:map00561	Glycerolipid metabolism
# path:map00562	Inositol phosphate metabolism
# path:map00563	Glycosylphosphatidylinositol (GPI)-anchor biosynthesis
# path:map00564	Glycerophospholipid metabolism
# path:map00565	Ether lipid metabolism
# path:map00571	Lipoarabinomannan (LAM) biosynthesis
# path:map00572	Arabinogalactan biosynthesis - Mycobacterium
# path:map00590	Arachidonic acid metabolism
# path:map00591	Linoleic acid metabolism
# path:map00592	alpha-Linolenic acid metabolism
# path:map00600	Sphingolipid metabolism
# path:map00601	Glycosphingolipid biosynthesis - lacto and neolacto series
# path:map00603	Glycosphingolipid biosynthesis - globo and isoglobo series
# path:map00604	Glycosphingolipid biosynthesis - ganglio series
# path:map00620	Pyruvate metabolism
# path:map00621	Dioxin degradation
# path:map00622	Xylene degradation
# path:map00623	Toluene degradation
# path:map00624	Polycyclic aromatic hydrocarbon degradation
# path:map00625	Chloroalkane and chloroalkene degradation
# path:map00626	Naphthalene degradation
# path:map00627	Aminobenzoate degradation
# path:map00630	Glyoxylate and dicarboxylate metabolism
# path:map00633	Nitrotoluene degradation
# path:map00640	Propanoate metabolism
# path:map00642	Ethylbenzene degradation
# path:map00643	Styrene degradation
# path:map00650	Butanoate metabolism
# path:map00660	C5-Branched dibasic acid metabolism
# path:map00670	One carbon pool by folate
# path:map00680	Methane metabolism
# path:map00710	Carbon fixation in photosynthetic organisms
# path:map00720	Carbon fixation pathways in prokaryotes
# path:map00730	Thiamine metabolism
# path:map00740	Riboflavin metabolism
# path:map00750	Vitamin B6 metabolism
# path:map00760	Nicotinate and nicotinamide metabolism
# path:map00770	Pantothenate and CoA biosynthesis
# path:map00780	Biotin metabolism
# path:map00785	Lipoic acid metabolism
# path:map00790	Folate biosynthesis
# path:map00791	Atrazine degradation
# path:map00830	Retinol metabolism
# path:map00860	Porphyrin and chlorophyll metabolism
# path:map00900	Terpenoid backbone biosynthesis
# path:map00901	Indole alkaloid biosynthesis
# path:map00902	Monoterpenoid biosynthesis
# path:map00903	Limonene and pinene degradation
# path:map00904	Diterpenoid biosynthesis
# path:map00905	Brassinosteroid biosynthesis
# path:map00906	Carotenoid biosynthesis
# path:map00908	Zeatin biosynthesis
# path:map00909	Sesquiterpenoid and triterpenoid biosynthesis
# path:map00910	Nitrogen metabolism
# path:map00920	Sulfur metabolism
# path:map00930	Caprolactam degradation
# path:map00940	Phenylpropanoid biosynthesis
# path:map00941	Flavonoid biosynthesis
# path:map00942	Anthocyanin biosynthesis
# path:map00943	Isoflavonoid biosynthesis
# path:map00944	Flavone and flavonol biosynthesis
# path:map00945	Stilbenoid, diarylheptanoid and gingerol biosynthesis
# path:map00950	Isoquinoline alkaloid biosynthesis
# path:map00960	Tropane, piperidine and pyridine alkaloid biosynthesis
# path:map00965	Betalain biosynthesis
# path:map00966	Glucosinolate biosynthesis
# path:map00970	Aminoacyl-tRNA biosynthesis
# path:map00980	Metabolism of xenobiotics by cytochrome P450
# path:map00981	Insect hormone biosynthesis
# path:map00982	Drug metabolism - cytochrome P450
# path:map00983	Drug metabolism - other enzymes
# path:map00984	Steroid degradation
# path:map00997	Biosynthesis of various secondary metabolites - part 3
# path:map00998	Biosynthesis of various secondary metabolites - part 2
# path:map00999	Biosynthesis of various secondary metabolites - part 1
# path:map01010	Overview of biosynthetic pathways
# path:map01040	Biosynthesis of unsaturated fatty acids
# path:map01051	Biosynthesis of ansamycins
# path:map01052	Type I polyketide structures
# path:map01053	Biosynthesis of siderophore group nonribosomal peptides
# path:map01054	Nonribosomal peptide structures
# path:map01055	Biosynthesis of vancomycin group antibiotics
# path:map01056	Biosynthesis of type II polyketide backbone
# path:map01057	Biosynthesis of type II polyketide products
# path:map01058	Acridone alkaloid biosynthesis
# path:map01059	Biosynthesis of enediyne antibiotics
# path:map01060	Biosynthesis of plant secondary metabolites
# path:map01061	Biosynthesis of phenylpropanoids
# path:map01062	Biosynthesis of terpenoids and steroids
# path:map01063	Biosynthesis of alkaloids derived from shikimate pathway
# path:map01064	Biosynthesis of alkaloids derived from ornithine, lysine and nicotinic acid
# path:map01065	Biosynthesis of alkaloids derived from histidine and purine
# path:map01066	Biosynthesis of alkaloids derived from terpenoid and polyketide
# path:map01070	Biosynthesis of plant hormones
# path:map01100	Metabolic pathways
# path:map01110	Biosynthesis of secondary metabolites
# path:map01120	Microbial metabolism in diverse environments
# path:map01200	Carbon metabolism
# path:map01210	2-Oxocarboxylic acid metabolism
# path:map01212	Fatty acid metabolism
# path:map01220	Degradation of aromatic compounds
# path:map01230	Biosynthesis of amino acids
# path:map01501	beta-Lactam resistance
# path:map01502	Vancomycin resistance
# path:map01503	Cationic antimicrobial peptide (CAMP) resistance
# path:map01521	EGFR tyrosine kinase inhibitor resistance
# path:map01522	Endocrine resistance
# path:map01523	Antifolate resistance
# path:map01524	Platinum drug resistance
# path:map02010	ABC transporters
# path:map02020	Two-component system
# path:map02024	Quorum sensing
# path:map02025	Biofilm formation - Pseudomonas aeruginosa
# path:map02026	Biofilm formation - Escherichia coli
# path:map02030	Bacterial chemotaxis
# path:map02040	Flagellar assembly
# path:map02060	Phosphotransferase system (PTS)
# path:map03008	Ribosome biogenesis in eukaryotes
# path:map03010	Ribosome
# path:map03013	RNA transport
# path:map03015	mRNA surveillance pathway
# path:map03018	RNA degradation
# path:map03020	RNA polymerase
# path:map03022	Basal transcription factors
# path:map03030	DNA replication
# path:map03040	Spliceosome
# path:map03050	Proteasome
# path:map03060	Protein export
# path:map03070	Bacterial secretion system
# path:map03320	PPAR signaling pathway
# path:map03410	Base excision repair
# path:map03420	Nucleotide excision repair
# path:map03430	Mismatch repair
# path:map03440	Homologous recombination
# path:map03450	Non-homologous end-joining
# path:map03460	Fanconi anemia pathway
# path:map04010	MAPK signaling pathway
# path:map04011	MAPK signaling pathway - yeast
# path:map04012	ErbB signaling pathway
# path:map04013	MAPK signaling pathway - fly
# path:map04014	Ras signaling pathway
# path:map04015	Rap1 signaling pathway
# path:map04016	MAPK signaling pathway - plant
# path:map04020	Calcium signaling pathway
# path:map04022	cGMP-PKG signaling pathway
# path:map04024	cAMP signaling pathway
# path:map04060	Cytokine-cytokine receptor interaction
# path:map04061	Viral protein interaction with cytokine and cytokine receptor
# path:map04062	Chemokine signaling pathway
# path:map04064	NF-kappa B signaling pathway
# path:map04066	HIF-1 signaling pathway
# path:map04068	FoxO signaling pathway
# path:map04070	Phosphatidylinositol signaling system
# path:map04071	Sphingolipid signaling pathway
# path:map04072	Phospholipase D signaling pathway
# path:map04075	Plant hormone signal transduction
# path:map04080	Neuroactive ligand-receptor interaction
# path:map04110	Cell cycle
# path:map04111	Cell cycle - yeast
# path:map04112	Cell cycle - Caulobacter
# path:map04113	Meiosis - yeast
# path:map04114	Oocyte meiosis
# path:map04115	p53 signaling pathway
# path:map04120	Ubiquitin mediated proteolysis
# path:map04122	Sulfur relay system
# path:map04130	SNARE interactions in vesicular transport
# path:map04136	Autophagy - other
# path:map04137	Mitophagy - animal
# path:map04138	Autophagy - yeast
# path:map04139	Mitophagy - yeast
# path:map04140	Autophagy - animal
# path:map04141	Protein processing in endoplasmic reticulum
# path:map04142	Lysosome
# path:map04144	Endocytosis
# path:map04145	Phagosome
# path:map04146	Peroxisome
# path:map04150	mTOR signaling pathway
# path:map04151	PI3K-Akt signaling pathway
# path:map04152	AMPK signaling pathway
# path:map04210	Apoptosis
# path:map04211	Longevity regulating pathway
# path:map04212	Longevity regulating pathway - worm
# path:map04213	Longevity regulating pathway - multiple species
# path:map04214	Apoptosis - fly
# path:map04215	Apoptosis - multiple species
# path:map04216	Ferroptosis
# path:map04217	Necroptosis
# path:map04218	Cellular senescence
# path:map04260	Cardiac muscle contraction
# path:map04261	Adrenergic signaling in cardiomyocytes
# path:map04270	Vascular smooth muscle contraction
# path:map04310	Wnt signaling pathway
# path:map04320	Dorso-ventral axis formation
# path:map04330	Notch signaling pathway
# path:map04340	Hedgehog signaling pathway
# path:map04341	Hedgehog signaling pathway - fly
# path:map04350	TGF-beta signaling pathway
# path:map04360	Axon guidance
# path:map04361	Axon regeneration
# path:map04370	VEGF signaling pathway
# path:map04371	Apelin signaling pathway
# path:map04380	Osteoclast differentiation
# path:map04390	Hippo signaling pathway
# path:map04391	Hippo signaling pathway - fly
# path:map04392	Hippo signaling pathway - multiple species
# path:map04510	Focal adhesion
# path:map04512	ECM-receptor interaction
# path:map04514	Cell adhesion molecules (CAMs)
# path:map04520	Adherens junction
# path:map04530	Tight junction
# path:map04540	Gap junction
# path:map04550	Signaling pathways regulating pluripotency of stem cells
# path:map04610	Complement and coagulation cascades
# path:map04611	Platelet activation
# path:map04612	Antigen processing and presentation
# path:map04614	Renin-angiotensin system
# path:map04620	Toll-like receptor signaling pathway
# path:map04621	NOD-like receptor signaling pathway
# path:map04622	RIG-I-like receptor signaling pathway
# path:map04623	Cytosolic DNA-sensing pathway
# path:map04624	Toll and Imd signaling pathway
# path:map04625	C-type lectin receptor signaling pathway
# path:map04626	Plant-pathogen interaction
# path:map04630	JAK-STAT signaling pathway
# path:map04640	Hematopoietic cell lineage
# path:map04650	Natural killer cell mediated cytotoxicity
# path:map04657	IL-17 signaling pathway
# path:map04658	Th1 and Th2 cell differentiation
# path:map04659	Th17 cell differentiation
# path:map04660	T cell receptor signaling pathway
# path:map04662	B cell receptor signaling pathway
# path:map04664	Fc epsilon RI signaling pathway
# path:map04666	Fc gamma R-mediated phagocytosis
# path:map04668	TNF signaling pathway
# path:map04670	Leukocyte transendothelial migration
# path:map04672	Intestinal immune network for IgA production
# path:map04710	Circadian rhythm
# path:map04711	Circadian rhythm - fly
# path:map04712	Circadian rhythm - plant
# path:map04713	Circadian entrainment
# path:map04714	Thermogenesis
# path:map04720	Long-term potentiation
# path:map04721	Synaptic vesicle cycle
# path:map04722	Neurotrophin signaling pathway
# path:map04723	Retrograde endocannabinoid signaling
# path:map04724	Glutamatergic synapse
# path:map04725	Cholinergic synapse
# path:map04726	Serotonergic synapse
# path:map04727	GABAergic synapse
# path:map04728	Dopaminergic synapse
# path:map04730	Long-term depression
# path:map04740	Olfactory transduction
# path:map04742	Taste transduction
# path:map04744	Phototransduction
# path:map04745	Phototransduction - fly
# path:map04750	Inflammatory mediator regulation of TRP channels
# path:map04810	Regulation of actin cytoskeleton
# path:map04910	Insulin signaling pathway
# path:map04911	Insulin secretion
# path:map04912	GnRH signaling pathway
# path:map04913	Ovarian steroidogenesis
# path:map04914	Progesterone-mediated oocyte maturation
# path:map04915	Estrogen signaling pathway
# path:map04916	Melanogenesis
# path:map04917	Prolactin signaling pathway
# path:map04918	Thyroid hormone synthesis
# path:map04919	Thyroid hormone signaling pathway
# path:map04920	Adipocytokine signaling pathway
# path:map04921	Oxytocin signaling pathway
# path:map04922	Glucagon signaling pathway
# path:map04923	Regulation of lipolysis in adipocytes
# path:map04924	Renin secretion
# path:map04925	Aldosterone synthesis and secretion
# path:map04926	Relaxin signaling pathway
# path:map04927	Cortisol synthesis and secretion
# path:map04928	Parathyroid hormone synthesis, secretion and action
# path:map04929	GnRH secretion
# path:map04930	Type II diabetes mellitus
# path:map04931	Insulin resistance
# path:map04932	Non-alcoholic fatty liver disease (NAFLD)
# path:map04933	AGE-RAGE signaling pathway in diabetic complications
# path:map04934	Cushing syndrome
# path:map04935	Growth hormone synthesis, secretion and action
# path:map04940	Type I diabetes mellitus
# path:map04950	Maturity onset diabetes of the young
# path:map04960	Aldosterone-regulated sodium reabsorption
# path:map04961	Endocrine and other factor-regulated calcium reabsorption
# path:map04962	Vasopressin-regulated water reabsorption
# path:map04964	Proximal tubule bicarbonate reclamation
# path:map04966	Collecting duct acid secretion
# path:map04970	Salivary secretion
# path:map04971	Gastric acid secretion
# path:map04972	Pancreatic secretion
# path:map04973	Carbohydrate digestion and absorption
# path:map04974	Protein digestion and absorption
# path:map04975	Fat digestion and absorption
# path:map04976	Bile secretion
# path:map04977	Vitamin digestion and absorption
# path:map04978	Mineral absorption
# path:map04979	Cholesterol metabolism
# path:map05010	Alzheimer disease
# path:map05012	Parkinson disease
# path:map05014	Amyotrophic lateral sclerosis (ALS)
# path:map05016	Huntington disease
# path:map05017	Spinocerebellar ataxia
# path:map05020	Prion diseases
# path:map05030	Cocaine addiction
# path:map05031	Amphetamine addiction
# path:map05032	Morphine addiction
# path:map05033	Nicotine addiction
# path:map05034	Alcoholism
# path:map05100	Bacterial invasion of epithelial cells
# path:map05110	Vibrio cholerae infection
# path:map05111	Biofilm formation - Vibrio cholerae
# path:map05120	Epithelial cell signaling in Helicobacter pylori infection
# path:map05130	Pathogenic Escherichia coli infection
# path:map05131	Shigellosis
# path:map05132	Salmonella infection
# path:map05133	Pertussis
# path:map05134	Legionellosis
# path:map05135	Yersinia infection
# path:map05140	Leishmaniasis
# path:map05142	Chagas disease (American trypanosomiasis)
# path:map05143	African trypanosomiasis
# path:map05144	Malaria
# path:map05145	Toxoplasmosis
# path:map05146	Amoebiasis
# path:map05150	Staphylococcus aureus infection
# path:map05152	Tuberculosis
# path:map05160	Hepatitis C
# path:map05161	Hepatitis B
# path:map05162	Measles
# path:map05163	Human cytomegalovirus infection
# path:map05164	Influenza A
# path:map05165	Human papillomavirus infection
# path:map05166	Human T-cell leukemia virus 1 infection
# path:map05167	Kaposi sarcoma-associated herpesvirus infection
# path:map05168	Herpes simplex virus 1 infection
# path:map05169	Epstein-Barr virus infection
# path:map05170	Human immunodeficiency virus 1 infection
# path:map05200	Pathways in cancer
# path:map05202	Transcriptional misregulation in cancer
# path:map05203	Viral carcinogenesis
# path:map05204	Chemical carcinogenesis
# path:map05205	Proteoglycans in cancer
# path:map05206	MicroRNAs in cancer
# path:map05210	Colorectal cancer
# path:map05211	Renal cell carcinoma
# path:map05212	Pancreatic cancer
# path:map05213	Endometrial cancer
# path:map05214	Glioma
# path:map05215	Prostate cancer
# path:map05216	Thyroid cancer
# path:map05217	Basal cell carcinoma
# path:map05218	Melanoma
# path:map05219	Bladder cancer
# path:map05220	Chronic myeloid leukemia
# path:map05221	Acute myeloid leukemia
# path:map05222	Small cell lung cancer
# path:map05223	Non-small cell lung cancer
# path:map05224	Breast cancer
# path:map05225	Hepatocellular carcinoma
# path:map05226	Gastric cancer
# path:map05230	Central carbon metabolism in cancer
# path:map05231	Choline metabolism in cancer
# path:map05235	PD-L1 expression and PD-1 checkpoint pathway in cancer
# path:map05310	Asthma
# path:map05320	Autoimmune thyroid disease
# path:map05321	Inflammatory bowel disease (IBD)
# path:map05322	Systemic lupus erythematosus
# path:map05323	Rheumatoid arthritis
# path:map05330	Allograft rejection
# path:map05332	Graft-versus-host disease
# path:map05340	Primary immunodeficiency
# path:map05410	Hypertrophic cardiomyopathy (HCM)
# path:map05412	Arrhythmogenic right ventricular cardiomyopathy (ARVC)
# path:map05414	Dilated cardiomyopathy (DCM)
# path:map05416	Viral myocarditis
# path:map05418	Fluid shear stress and atherosclerosis
# path:map07011	Penicillins
# path:map07012	Cephalosporins - parenteral agents
# path:map07013	Cephalosporins - oral agents
# path:map07014	Quinolones
# path:map07015	Local analgesics
# path:map07016	Sulfonamide derivatives - sulfa drugs
# path:map07017	Sulfonamide derivatives - diuretics
# path:map07018	Sulfonamide derivatives - hypoglycemic agents
# path:map07019	Tetracyclines
# path:map07020	Macrolides and ketolides
# path:map07021	Aminoglycosides
# path:map07023	Rifamycins
# path:map07024	HMG-CoA reductase inhibitors
# path:map07025	Quinolines
# path:map07026	Antifungal agents
# path:map07027	Antidepressants
# path:map07028	Antipsychotics
# path:map07029	Antipsychotics - phenothiazines
# path:map07030	Anxiolytics
# path:map07031	Antipsychotics - butyrophenones
# path:map07032	Hypnotics
# path:map07033	Anticonvulsants
# path:map07034	Eicosanoids
# path:map07035	Prostaglandins
# path:map07036	Calcium channel blocking drugs
# path:map07037	Antiarrhythmic drugs
# path:map07038	Antiulcer drugs
# path:map07039	Opioid analgesics
# path:map07040	Antineoplastics - alkylating agents
# path:map07041	Antineoplastics - antimetabolic agents
# path:map07042	Antineoplastics - agents from natural products
# path:map07043	Antineoplastics - hormones
# path:map07044	Antiviral agents
# path:map07045	Antineoplastics - protein kinases inhibitors
# path:map07046	Immunosuppressive agents
# path:map07047	Osteoporosis drugs
# path:map07048	Antimigraines
# path:map07049	Antithrombosis agents
# path:map07050	Antirheumatics - DMARDs and biological agents
# path:map07051	Antidiabetics
# path:map07052	Antidyslipidemic agents
# path:map07053	Anti-HIV agents
# path:map07054	Antiglaucoma agents
# path:map07055	Sulfonamide derivatives - overview
# path:map07056	Agents for Alzheimer-type dementia
# path:map07057	Antiparkinsonian agents
# path:map07110	Benzoic acid family
# path:map07112	1,2-Diphenyl substitution family
# path:map07114	Naphthalene family
# path:map07117	Benzodiazepine family
# path:map07211	Serotonin receptor agonists/antagonists
# path:map07212	Histamine H1 receptor antagonists
# path:map07213	Dopamine receptor agonists/antagonists
# path:map07214	beta-Adrenergic receptor agonists/antagonists
# path:map07215	alpha-Adrenergic receptor agonists/antagonists
# path:map07216	Catecholamine transferase inhibitors
# path:map07217	Renin-angiotensin system inhibitors
# path:map07218	HIV protease inhibitors
# path:map07219	Cyclooxygenase inhibitors
# path:map07220	Cholinergic and anticholinergic drugs
# path:map07221	Nicotinic cholinergic receptor antagonists
# path:map07222	Peroxisome proliferator-activated receptor (PPAR) agonists
# path:map07223	Retinoic acid receptor (RAR) and retinoid X receptor (RXR) agonists/antagonists
# path:map07224	Opioid receptor agonists/antagonists
# path:map07225	Glucocorticoid and mineralocorticoid receptor agonists/antagonists
# path:map07226	Progesterone, androgen and estrogen receptor agonists/antagonists
# path:map07227	Histamine H2/H3 receptor agonists/antagonists
# path:map07228	Eicosanoid receptor agonists/antagonists
# path:map07229	Angiotensin receptor and endothelin receptor antagonists
# path:map07230	GABA-A receptor agonists/antagonists
# path:map07231	Sodium channel blocking drugs
# path:map07232	Potassium channel blocking and opening drugs
# path:map07233	Ion transporter inhibitors
# path:map07234	Neurotransmitter transporter inhibitors
# path:map07235	N-Metyl-D-aspartic acid receptor antagonists

# %%
orgs = REST.kegg_list("organism")
orgs = list(orgs)

# %%
keggConv = kegg_conv('tcr', "ncbi-proteinid").read()

# %%
print(keggConv)
# Out:
# ncbi-proteinid:XP_802622	tcr:397923.10
# ncbi-proteinid:XP_802481	tcr:397937.10
# ncbi-proteinid:XP_802482	tcr:397937.5
# ncbi-proteinid:XP_802144	tcr:398235.10
# ncbi-proteinid:XP_802145	tcr:398235.20
# ncbi-proteinid:XP_802488	tcr:398265.9
# ncbi-proteinid:XP_802702	tcr:398343.9
# ncbi-proteinid:XP_802294	tcr:398345.10
# ncbi-proteinid:XP_804171	tcr:398477.10
# ncbi-proteinid:XP_802142	tcr:398751.10
# ncbi-proteinid:XP_802855	tcr:399033.10
# ncbi-proteinid:XP_802856	tcr:399033.19
# ncbi-proteinid:XP_802153	tcr:399245.9
# ncbi-proteinid:XP_804452	tcr:399373.20
# ncbi-proteinid:XP_804453	tcr:399373.9
# ncbi-proteinid:XP_805501	tcr:399389.10
# ncbi-proteinid:XP_802345	tcr:399997.10
# ncbi-proteinid:XP_802312	tcr:400739.10
# ncbi-proteinid:XP_802713	tcr:401469.10
# ncbi-proteinid:XP_802714	tcr:401469.20
# ncbi-proteinid:XP_802241	tcr:401473.9
# ncbi-proteinid:XP_802427	tcr:401569.10
# ncbi-proteinid:XP_802286	tcr:401961.10
# ncbi-proteinid:XP_802215	tcr:402647.9
# ncbi-proteinid:XP_804071	tcr:402857.10
# ncbi-proteinid:XP_804072	tcr:402857.20
# ncbi-proteinid:XP_813645	tcr:511923.130
# ncbi-proteinid:XP_813641	tcr:511923.30
# ncbi-proteinid:XP_813642	tcr:511923.60
# ncbi-proteinid:XP_807874	tcr:511925.10
# ncbi-proteinid:XP_807875	tcr:511925.20
# ncbi-proteinid:XP_807876	tcr:511925.40
# ncbi-proteinid:XP_807877	tcr:511925.50
# ncbi-proteinid:XP_807878	tcr:511925.60
# ncbi-proteinid:XP_807879	tcr:511925.70
# ncbi-proteinid:XP_803035	tcr:511927.10
# ncbi-proteinid:XP_803036	tcr:511927.20
# ncbi-proteinid:XP_803037	tcr:511927.30
# ncbi-proteinid:XP_808588	tcr:511929.30

# %%
from Bio.KEGG import Gene
from Bio.KEGG import REST

geneName = 'YOL097C'
orgCode = 'sce'
gene_id = orgCode + ':' + geneName

print('GENE ID: ', gene_id, '\n')
# Out:
# GENE ID:  sce:YOL097C

# %%
request = REST.kegg_get(gene_id)
records = Gene.parse(request)
for record in records:
    m = record.__dict__
    print('entry ', record.entry)
    print('name ', record.name)
    print('definition ', record.definition)
    print('orthology ', record.orthology)
    print('organism ', record.organism)
    print('position ', record.position)
    print('motif ', record.motif)
    print('dblinks ', record.dblinks)
# Out:
# entry  YOL097C
# name  ['WRS1, HRE342']
# definition  (RefSeq) tryptophan--tRNA ligase WRS1
# orthology  [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# organism  ('sce', 'Saccharomyces cerevisiae (budding yeast)')
# position  XV:complement(136527..137825)
# motif  [('Pfam', ['tRNA-synt_1b'])]
# dblinks  [('NCBI-GeneID', ['854056']), ('NCBI-ProteinID', ['NP_014544']), ('SGD', ['S000005457']), ('UniProt', ['Q12109'])]

# %%
print(m)
# Out:
# {'entry': 'YOL097C', 'name': ['WRS1, HRE342'], 'definition': '(RefSeq) tryptophan--tRNA ligase WRS1', 'orthology': [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')], 'organism': ('sce', 'Saccharomyces cerevisiae (budding yeast)'), 'position': 'XV:complement(136527..137825)', 'motif': [('Pfam', ['tRNA-synt_1b'])], 'dblinks': [('NCBI-GeneID', ['854056']), ('NCBI-ProteinID', ['NP_014544']), ('SGD', ['S000005457']), ('UniProt', ['Q12109'])]}

# %%
# for getting a sequence of the gene
request = REST.kegg_get(gene_id).read()
sequence = request.split('NTSEQ')[1].split('1299')[1].replace('\n', '').replace(' ', '').replace('///', '')
len(sequence)
# Out:
# 1299

# %%
from Bio.KEGG import Enzyme
ec_id = 'ec:' + '6.1.1.2'
print('EC NUMBER: ', ec_id, '\n')

request = REST.kegg_get(ec_id)

records= Enzyme.parse(request)

for record in records:
    record_dict = record.__dict__
    print('ENTRY: ', record.entry)
    print('NAME: ', record.name)
    print('CLASSNAME: ', record.classname)
    print('SYSNAME: ', record.sysname)
    print('REACTION: ', record.reaction)
    print('PATHWAYS: ', record.pathway)
    print('GENES: ', record.genes)
    print('DBLINKS: ', record.dblinks)
# Out:
# EC NUMBER:  ec:6.1.1.2
#
# ENTRY:  6.1.1.2
'101358847']), ('MDO', ['100012545', '100018040']), ('SHR', ['100917602', '100932412']), ('PCW', ['110219618', '110222396']), ('OAA', ['100082333', '100087133']), ('GGA', ['101750690', '423458']), ('MGP', ['100542823', '100546404']), ('CJO', ['107315331', '107319382']), ('NMEL', ['110398873', '110400805']), ('APLA', ['101792334', '101802484']), ('ACYG', ['106036003', '106045749']), ('TGU', ['100217769', '100232577']), ('LSR', ['110480785', '110481204']), ('SCAN', ['103826428', '103827134']), ('GFR', ['102039238', '102045116']), ('FAB', ['101818421', '101818712']), ('PHI', ['102101897', '102113669']), ('PMAJ', ['107205547', '107209682']), ('CCAE', ['111929816', '111938603']), ('CCW', ['104686463', '104687103']), ('ETL', ['114058178', '114064455']), ('FPG', ['101916232', '101918605']), ('FCH', ['102052655', '102053048']), ('CLV', ['102087099', '102087522']), ('EGZ', ['104124509', '104126581']), ('NNI', ['104008650', '104014822']), ('ACUN', ['113479348', '113480321']), ('PADL', ['103920358', '103921240']), ('AAM', ['106482964', '106497260']), ('ASN', ['102368292', '102373177']), ('AMJ', ['102557915', '102566579']), ('PSS', ['102450662', '102452748']), ('CMY', ['102935335', '102938556']), ('CPIC', ['101936414', '101952322']), ('ACS', ['100553394', '100562093']), ('PVT', ['110076954', '110078928']), ('PBI', ['103049348', '103055453']), ('PMUR', ['107285817', '107291422']), ('TSR', ['106542704', '106555997']), ('PMUA', ['114586400', '114587705']), ('GJA', ['107111009', '107121528']), ('XLA', ['108707799', '108709294', '380225', '414492']), ('XTR', ['101731027', '734080']), ('NPR', ['108800089', '108802531']), ('DRE', ['108179007', '393745', '503745']), ('SRX', ['107712263', '107719695', '107724450', '107743907']), ('SANH', ['1 ...
# DBLINKS:  [('ExplorEnz - The Enzyme Database', ['6.1.1.2']), ('IUBMB Enzyme Nomenclature', ['6.1.1.2']), ('ExPASy - ENZYME nomenclature database', ['6.1.1.2']), ('BRENDA, the Enzyme Database', ['6.1.1.2']), ('CAS', ['9023-44-3'])]

# %%
record_dict.keys()
# Out:
# dict_keys(['entry', 'name', 'classname', 'sysname', 'reaction', 'substrate', 'product', 'inhibitor', 'cofactor', 'effector', 'comment', 'pathway', 'genes', 'disease', 'structures', 'dblinks'])

# %%
from Bio.KEGG import Compound

comp_id = 'cpd:' + 'C00002'
print('Compound Id: ', comp_id, '\n')

request = REST.kegg_get(comp_id)

records= Compound.parse(request)

for record in records:
    print('entry ', record.entry)
    print('name ', record.name)
    print('formula ', record.formula)
    print('mass ', record.mass)
    print('enzyme ', record.enzyme)
    print('structures ', record.structures)
    print('dblinks ', record.dblinks)
# Out:
# Compound Id:  cpd:C00002
#
# entry  C00002
# name  ['ATP', "Adenosine 5'-triphosphate"]
# formula  C10H16N5O13P3
# mass
7', '2.7.3.8', '2.7.3.10', '2.7.3.13', '2.7.4.1', '2.7.4.2', '2.7.4.3', '2.7.4.4', '2.7.4.6', '2.7.4.7', '2.7.4.8', '2.7.4.9', '2.7.4.11', '2.7.4.12', '2.7.4.13', '2.7.4.14', '2.7.4.15', '2.7.4.16', '2.7.4.18', '2.7.4.19', '2.7.4.21', '2.7.4.22', '2.7.4.23', '2.7.4.24', '2.7.4.25', '2.7.4.26', '2.7.4.31', '2.7.4.-', '2.7.6.1', '2.7.6.2', '2.7.6.3', '2.7.6.4', '2.7.6.5', '2.7.7.1', '2.7.7.2', '2.7.7.3', '2.7.7.4', '2.7.7.6', '2.7.7.18', '2.7.7.19', '2.7.7.27', '2.7.7.42', '2.7.7.46', '2.7.7.47', '2.7.7.48', '2.7.7.53', '2.7.7.58', '2.7.7.70', '2.7.7.72', '2.7.7.73', '2.7.7.75', '2.7.7.80', '2.7.7.84', '2.7.7.85', '2.7.7.86', '2.7.7.87', '2.7.7.96', '2.7.7.97', '2.7.7.100', '2.7.8.37', '2.7.9.1', '2.7.9.2', '2.7.9.3', '2.7.9.6', '2.7.9.-', '2.7.10.1', '2.7.10.2', '2.7.11.1', '2.7.11.2', '2.7.11.3', '2.7.11.4', '2.7.11.5', '2.7.11.6', '2.7.11.7', '2.7.11.8', '2.7.11.9', '2.7.11.10', '2.7.11.11', '2.7.11.12', '2.7.11.13', '2.7.11.14', '2.7.11.15', '2.7.11.17', '2.7.11.18', '2.7.11.19', '2.7.11.21', '2.7.11.22', '2.7.11.23', '2.7.11.24', '2.7.11.25', '2.7.11.26', '2.7.11.27', '2.7.11.28', '2.7.11.29', '2.7.11.30', '2.7.11.31', '2.7.12.1', '2.7.12.2', '2.7.13.1', '2.7.13.2', '2.7.14.1', '2.8.1.13', '3.5.2.9', '3.5.2.14', '3.5.4.17', '3.5.4.18', '3.6.1.3', '3.6.1.5', '3.6.1.8', '3.6.1.9', '3.6.1.14', '3.6.1.15', '3.6.1.17', '3.6.1.61', '4.1.1.33', '4.1.1.49', '4.1.1.99', '4.2.1.93', '4.4.1.37', '4.6.1.1', '4.6.1.-', '5.1.1.11', '5.1.1.23', '6.1.1.1', '6.1.1.2', '6.1.1.3', '6.1.1.4', '6.1.1.5', '6.1.1.6', '6.1.1.7', '6.1.1.9', '6.1.1.10', '6.1.1.11', '6.1.1.12', '6.1.1.13', '6.1.1.14', '6.1.1.15', '6.1.1.16', '6.1.1.17', '6.1.1.18', '6.1.1.19', '6.1.1.20', '6.1.1.21', '6.1.1.22' ...
# structures  []
# dblinks  [('CAS', ['56-65-5']), ('PubChem', ['3304']), ('ChEBI', ['15422']), ('ChEMBL', ['CHEMBL14249']), ('KNApSAcK', ['C00001491']), ('PDB-CCD', ['ATP']), ('3DMET', ['B01125']), ('NIKKAJI', ['J10.680A'])]

# %%
request = REST.kegg_get('rn:R00193').read()
print(request)

# C --> COMPOUND
# Out:
# ENTRY       R00193                      Reaction
# NAME        S-Adenosyl-L-homocysteine aminohydrolase
# DEFINITION  S-Adenosyl-L-homocysteine + H2O <=> S-Inosyl-L-homocysteine + Ammonia
# EQUATION    C00021 + C00001 <=> C03431 + C00014
# RCLASS      RC01168  C00021_C03431
# ENZYME      3.5.4.28
# DBLINKS     RHEA: 20719
# ///

# %%
import pandas as pd
blastResultsdf = pd.read_excel("./data/dfAllBlastResults_DRR076693.3.xlsx")

# %%
def getGeneinfo(gene_id):
    request = REST.kegg_get(gene_id)
    records= Gene.parse(request)
    return records

def getEnzymeinfo(enzyme_id):
    request = REST.kegg_get(enzyme_id)
    records= Enzyme.parse(request)
    return records

# %%
blastResultsdf
# Out:
#     Unnamed: 0                 QueryName  \
# 0            0  DRR076693.3 3 length=522
# 1            1  DRR076693.3 3 length=522
# 2            2  DRR076693.3 3 length=522
# 3            3  DRR076693.3 3 length=522
# 4            4  DRR076693.3 3 length=522
# 5            5  DRR076693.3 3 length=522
# 6            6  DRR076693.3 3 length=522
# 7            7  DRR076693.3 3 length=522
# 8            8  DRR076693.3 3 length=522
# 9            9  DRR076693.3 3 length=522
# 10          10  DRR076693.3 3 length=522
# 11          11  DRR076693.3 3 length=522
#
#                                           Description        E-value  \
# 0   tryptophan--tRNA ligase WRS1 [Saccharomyces ce...  [5.36634e-20]
# 1   hypothetical protein Kpol_495p25 [Vanderwaltoz...  [2.47237e-19]
# 2         WRS1-like protein [Saccharomyces eubayanus]  [3.42091e-19]
# 3                  HBL382Wp [Eremothecium sinecaudum]  [1.09368e-18]
# 4   hypothetical protein NCAS_0C04960 [Naumovozyma...  [1.47747e-18]
# 5    KLTH0C09768p [Lachancea thermotolerans CBS 6340]  [3.02664e-18]
# 6   uncharacterized protein KLLA0_B07733g [Kluyver...  [3.03265e-18]
# 7   hypothetical protein TPHA_0P01010 [Tetrapisisp...  [4.16475e-18]
# 8   tryptophanyl-tRNA synthetase [Ascoidea rubesce...  [4.73629e-18]
# 9   uncharacterized protein LALA0_S08e02520g [Lach...  [4.96565e-18]
# 10  hypothetical protein TBLA_0B02320 [Tetrapisisp...  [5.16695e-18]
# 11  hypothetical protein PICMEDRAFT_29905 [Pichia ...  [6.60316e-18]
#
#          NCBI ID           KEGG ID                             Organism  \
# 0      NP_014544       sce:YOL097C       Saccharomyces cerevisiae S288C
# 1   XP_001643885   vpo:Kpol_495p25  Vanderwaltozyma polyspora DSM 70294
# 2   XP_018221696               NaN              Saccharomyces eubayanus
# 3   XP_017985516               NaN              Eremothecium sinecaudum
# 4   XP_003675850  ncs:NCAS_0C04960       Naumovozyma castellii CBS 4309
# 5   XP_002552643  lth:KLTH0C09768g    Lachancea thermotolerans CBS 6340
# 6      XP_451874  kla:KLLA0B07733g                 Kluyveromyces lactis
# 7   XP_003688693  tpf:TPHA_0P01010      Tetrapisispora phaffii CBS 4417
# 8   XP_020045051               NaN          Ascoidea rubescens DSM 1968
# 9   XP_022629658               NaN              Lachancea lanzarotensis
# 10  XP_004178593  tbl:TBLA_0B02320      Tetrapisispora blattae CBS 6284
# 11  XP_019019893               NaN   Pichia membranifaciens NRRL Y-2026
#
#     Length
# 0      432
# 1      432
# 2      433
# 3      429
# 4      435
# 5      426
# 6      432
# 7      430
# 8      428
# 9      422
# 10     415
# 11     427

# %%
dfHits = pd.DataFrame(columns=['ENTRY', 'NAME', 'DEFINITION', 'MOTIF', 'ORTHOLOGY', 'DBLINKS', 'ORGANISM'])

for b in blastResultsdf['KEGG ID']:
    try:
        if type(b) != float:
            print('Gene Name: ', b)
            records = getGeneinfo(b)
            for record in records:
                entry = record.entry
                name = record.name
                defin = record.definition
                mot = record.motif
                orth = record.orthology
                link = record.dblinks
                org = record.organism
            dfHits = dfHits.append({'ENTRY':entry, 'NAME':name, 'DEFINITION':defin, 'MOTIF':mot, 'ORTHOLOGY':orth,
                                    'DBLINKS':link, 'ORGANISM':org}, ignore_index=True)
    except:
        dfHits = dfHits.append({'ENTRY':'', 'NAME':'', 'DEFINITION':'', 'MOTIF':'', 'ORTHOLOGY':'',
                                    'DBLINKS':'', 'ORGANISM':''}, ignore_index=True)
# Out:
# Gene Name:  sce:YOL097C
# Gene Name:  vpo:Kpol_495p25
# Gene Name:  ncs:NCAS_0C04960
# Gene Name:  lth:KLTH0C09768g
# Gene Name:  kla:KLLA0B07733g
# Gene Name:  tpf:TPHA_0P01010
# Gene Name:  tbl:TBLA_0B02320

# %%
for org in orgs:
    org_code = org.split()[1]
    if org_code == 'kla':
        print(org)
# Out:
# T01025	kla	Kluyveromyces lactis	Eukaryotes;Fungi;Ascomycetes;Saccharomycetes

# %%
dfHits
# Out:
#           ENTRY            NAME                             DEFINITION  \
# 0       YOL097C  [WRS1, HRE342]  (RefSeq) tryptophan--tRNA ligase WRS1
# 1   Kpol_495p25              []          (RefSeq) hypothetical protein
# 2  NCAS_0C04960   [NCAS0C04960]          (RefSeq) hypothetical protein
# 3  KLTH0C09768g              []                  (RefSeq) KLTH0C09768p
# 4
# 5  TPHA_0P01010   [TPHA0P01010]          (RefSeq) hypothetical protein
# 6  TBLA_0B02320   [TBLA0B02320]          (RefSeq) hypothetical protein
#
#                             MOTIF  \
# 0        [(Pfam, [tRNA-synt_1b])]
# 1        [(Pfam, [tRNA-synt_1b])]
# 2  [(Pfam, [tRNA-synt_1b, Sec7])]
# 3        [(Pfam, [tRNA-synt_1b])]
# 4
# 5        [(Pfam, [tRNA-synt_1b])]
# 6        [(Pfam, [tRNA-synt_1b])]
#
#                                            ORTHOLOGY  \
# 0  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
# 1  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
# 2  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
# 3  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
# 4
# 5  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
# 6  [(K01867, tryptophanyl-tRNA synthetase [EC:6.1...
#
#                                              DBLINKS  \
# 0  [(NCBI-GeneID, [854056]), (NCBI-ProteinID, [NP...
# 1  [(NCBI-GeneID, [5544124]), (NCBI-ProteinID, [X...
# 2  [(NCBI-GeneID, [11528192]), (NCBI-ProteinID, [...
# 3  [(NCBI-GeneID, [8291523]), (NCBI-ProteinID, [X...
# 4
# 5  [(NCBI-GeneID, [11530878]), (NCBI-ProteinID, [...
# 6  [(NCBI-GeneID, [14494251]), (NCBI-ProteinID, [...
#
#                                           ORGANISM
# 0  (sce, Saccharomyces cerevisiae (budding yeast))
# 1                 (vpo, Vanderwaltozyma polyspora)
# 2                     (ncs, Naumovozyma castellii)
# 3                  (lth, Lachancea thermotolerans)
# 4
# 5                    (tpf, Tetrapisispora phaffii)
# 6                    (tbl, Tetrapisispora blattae)

# %%
from Bio.KEGG import Enzyme

dfEnzs = pd.DataFrame(columns=['ENTRY_enz','NAME_enz','REACTION', 'SUBSTRATE', 'PRODUCT', 'PATHWAY'])

for ort in dfHits['ORTHOLOGY']:
    if ort == '':
        dfEnzs = dfEnzs.append({'ENTRY_enz':'','NAME_enz':'','REACTION':'', 'SUBSTRATE':'', 
                            'PRODUCT':'', 'PATHWAY':''}, ignore_index=True)
    else:
        print(ort)
        ortInfo = ort[0][1]
        print('Orthology information: ', ortInfo)
        start = str(ortInfo).find('[')
        end = str(ortInfo).find(']')
        ecN = str(ortInfo)[start+1:end].lower()
        print('EC number: ', ecN)
        records = getEnzymeinfo(ecN)
        for record in records:
            entry = record.entry
            name = record.name
            rxn = record.reaction
            sub = record.substrate
            prod = record.product
            path = record.pathway
        dfEnzs = dfEnzs.append({'ENTRY_enz':entry,'NAME_enz':name,'REACTION':rxn, 'SUBSTRATE':sub, 
                                'PRODUCT':prod, 'PATHWAY':path}, ignore_index=True)
    print('\n')


dfAllInfo = pd.concat([dfHits, dfEnzs], axis=1)

dfAllInfo.columns = ['ENTRY', 'NAME', 'DEFINITION', 'MOTIF', 'ORTHOLOGY', 'DBLINKS', 'ORGANISM',
                    'ENTRY_enz','NAME_enz','REACTION', 'SUBSTRATE', 'PRODUCT', 'PATHWAY']
# Out:
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2
#
#
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2
#
#
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2
#
#
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2
#
#
#
#
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2
#
#
# [('K01867', 'tryptophanyl-tRNA synthetase [EC:6.1.1.2]')]
# Orthology information:  tryptophanyl-tRNA synthetase [EC:6.1.1.2]
# EC number:  ec:6.1.1.2

# %%
dfEnzs.head()
# Out:
#   ENTRY_enz                                           NAME_enz  \
# 0   6.1.1.2  [tryptophan---tRNA ligase, tryptophanyl-tRNA s...
# 1   6.1.1.2  [tryptophan---tRNA ligase, tryptophanyl-tRNA s...
# 2   6.1.1.2  [tryptophan---tRNA ligase, tryptophanyl-tRNA s...
# 3   6.1.1.2  [tryptophan---tRNA ligase, tryptophanyl-tRNA s...
# 4
#
#                                             REACTION  \
# 0  [ATP + L-tryptophan + tRNATrp = AMP + diphosph...
# 1  [ATP + L-tryptophan + tRNATrp = AMP + diphosph...
# 2  [ATP + L-tryptophan + tRNATrp = AMP + diphosph...
# 3  [ATP + L-tryptophan + tRNATrp = AMP + diphosph...
# 4
#
#                                            SUBSTRATE  \
# 0  [ATP [CPD:C00002], L-tryptophan [CPD:C00078], ...
# 1  [ATP [CPD:C00002], L-tryptophan [CPD:C00078], ...
# 2  [ATP [CPD:C00002], L-tryptophan [CPD:C00078], ...
# 3  [ATP [CPD:C00002], L-tryptophan [CPD:C00078], ...
# 4
#
#                                              PRODUCT  \
# 0  [AMP [CPD:C00020], diphosphate [CPD:C00013], L...
# 1  [AMP [CPD:C00020], diphosphate [CPD:C00013], L...
# 2  [AMP [CPD:C00020], diphosphate [CPD:C00013], L...
# 3  [AMP [CPD:C00020], diphosphate [CPD:C00013], L...
# 4
#
#                                           PATHWAY
# 0  [(PATH, ec00970, Aminoacyl-tRNA biosynthesis)]
# 1  [(PATH, ec00970, Aminoacyl-tRNA biosynthesis)]
# 2  [(PATH, ec00970, Aminoacyl-tRNA biosynthesis)]
# 3  [(PATH, ec00970, Aminoacyl-tRNA biosynthesis)]
# 4

# %%
for p in dfAllInfo['PATHWAY']:
    if p != '':
        print(p)
        print('Pathways ID: ', p[0][1])
        print('Pathways name: ', p[0][2], '\n')
# Out:
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis
#
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis
#
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis
#
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis
#
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis
#
# [('PATH', 'ec00970', 'Aminoacyl-tRNA biosynthesis')]
# Pathways ID:  ec00970
# Pathways name:  Aminoacyl-tRNA biosynthesis

# %%
import os
print(os.getcwd())
# Out:
# /Users/villons/Desktop/biosciences/Various assignment

# %%
from Bio.KEGG.KGML import KGML_parser
from Bio.KEGG.REST import *

from Bio.KEGG.KGML import KGML_pathway

def downloadKGMLfile(pathId, outputDir):
    kgmlMap = (kegg_get(pathId, "kgml").read())
    with open(os.path.join(outputDir, pathId +'.kgml'), 'w') as f:
        for m in kgmlMap:
            f.write(m)
            
lsPathways = []

for index, row in dfAllInfo.iterrows():    
    vals = list(row.values)
    if (vals.count(vals[0]) == len(vals)) == False:    
        pathID = row['PATHWAY'][0][1]
        print('pathID ', pathID)

        path = pathID.split('ec')[1]
        print('path ', path)

        organism = row['ORGANISM'][0]
        print('organism ', organism)

        gene = row['ENTRY']
        print('gene ', gene)

        mapID = organism + path
        print('mapID ', mapID)

        geneID = organism + ':' + gene
        print('geneID ', geneID)

        if mapID not in lsPathways:
            lsPathways.append(mapID)
            downloadKGMLfile(mapID, './')
            pMap = KGML_parser.read(kegg_get(mapID, "kgml"))
            for g in pMap.genes: 
                lsName = g.name.split()
                if geneID in lsName:
                    print(lsName, '\t', geneID, '\n')
                    for gg in g.graphics:
                        gg.fgcolor = '#ff0000'
                        gg.bgcolor = '#ff0000'

        kgml_map = KGMLCanvas(pMap, show_maps=True, import_imagemap = True)
        kgml_map.draw("./DRR076693.3.pdf")     
    
print('List of pathways: ', lsPathways)
# Out:
# pathID  ec00970
# path  00970
# organism  sce
# gene  YOL097C
# mapID  sce00970
# geneID  sce:YOL097C
# ['sce:YDR268W', 'sce:YOL097C'] 	 sce:YOL097C
#
# pathID  ec00970
# path  00970
# organism  vpo
# gene  Kpol_495p25
# mapID  vpo00970
# geneID  vpo:Kpol_495p25
# ['vpo:Kpol_495p25', 'vpo:Kpol_526p39'] 	 vpo:Kpol_495p25
#
# pathID  ec00970
# path  00970
# organism  ncs
# gene  NCAS_0C04960
# mapID  ncs00970
# geneID  ncs:NCAS_0C04960
# ['ncs:NCAS_0C04960', 'ncs:NCAS_0C05320'] 	 ncs:NCAS_0C04960
#
# pathID  ec00970
# path  00970
# organism  lth
# gene  KLTH0C09768g
# mapID  lth00970
# geneID  lth:KLTH0C09768g
# ['lth:KLTH0C09768g', 'lth:KLTH0F16808g'] 	 lth:KLTH0C09768g
#
# pathID  ec00970
# path  00970
# organism  tpf
# gene  TPHA_0P01010
# mapID  tpf00970
# geneID  tpf:TPHA_0P01010
# ['tpf:TPHA_0C00300', 'tpf:TPHA_0P01010'] 	 tpf:TPHA_0P01010
#
# pathID  ec00970
# path  00970
# organism  tbl
# gene  TBLA_0B02320
# mapID  tbl00970
# geneID  tbl:TBLA_0B02320
# ['tbl:TBLA_0A09590', 'tbl:TBLA_0B02320'] 	 tbl:TBLA_0B02320
#
# List of pathways:  ['sce00970', 'vpo00970', 'ncs00970', 'lth00970', 'tpf00970', 'tbl00970']

# %%
from Bio.Graphics.KGML_vis import KGMLCanvas

# %%
# Out:
# Requirement already satisfied: reportlab in /usr/local/lib/python3.7/site-packages (3.5.42)
# Requirement already satisfied: pillow>=4.0.0 in /usr/local/lib/python3.7/site-packages (from reportlab) (7.0.0)
# WARNING: You are using pip version 20.0.2; however, version 20.1.1 is available.
# You should consider upgrading via the '/usr/local/opt/python/bin/python3.7 -m pip install --upgrade pip' command.
